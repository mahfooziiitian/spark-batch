# %%
# %sql
CREATE TABLE IF NOT EXISTS poc.testing.employee (
    id INT,
    name VARCHAR(50),
    age INT,
    department VARCHAR(50)
);
# Out:
# <Empty result set>

# %%
# %sql
INSERT INTO poc.testing.employee (id, name, age, department) VALUES (1, 'John Doe', 30, 'IT');
INSERT INTO poc.testing.employee (id, name, age, department) VALUES (2, 'Jane Smith', 25, 'HR');
INSERT INTO poc.testing.employee (id, name, age, department) VALUES (3, 'Michael Johnson', 35, 'Finance');
INSERT INTO poc.testing.employee (id, name, age, department) VALUES (4, 'Mahfooz Doe', 30, 'HR');
# Out:
# <div style="height:300px;overflow:auto;resize:both;"><table style="width:100%" class="searchable sortable"><thead><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
select * from poc.testing.employee
# Out:
# <div style="height:300px;overflow:auto;resize:both;"><table style="width:100%" class="searchable sortable"><thead><tr><th>id</th><th>name</th><th>age</th><th>department</th></tr></thead><tbody><tr><td>3</td><td>Michael Johnson</td><td>35</td><td>Finance</td></tr><tr><td>4</td><td>Mahfooz Doe</td><td>30</td><td>HR</td></tr><tr><td>2</td><td>Jane Smith</td><td>25</td><td>HR</td></tr><tr><td>2</td><td>Jane Smith</td><td>25</td><td>HR</td></tr><tr><td>2</td><td>Jane Smith</td><td>25</td><td>HR</td></tr><tr><td>2</td><td>Jane Smith</td><td>25</td><td>HR</td></tr><tr><td>1</td><td>John Doe</td><td>30</td><td>IT</td></tr><tr><td>1</td><td>John Doe</td><td>30</td><td>IT</td></tr><tr><td>1</td><td>John Doe</td><td>30</td><td>IT</td></tr><tr><td>1</td><td>John Doe</td><td>30</td><td>IT</td></tr></tbody></table></div>

# %%
# %sql
drop table poc.testing.employee
# Out:
# <Empty result set>
