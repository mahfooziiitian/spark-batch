# %%
from pyspark.sql import SparkSession

# %%
spark = (SparkSession.builder.getOrCreate())

# %%
display(spark.sql("describe formatted system.compute.clusters"))
# Out:
# <div style="height:300px;overflow:auto;resize:both;"><table style="width:100%" class="searchable sortable"><thead><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>account_id</td><td>string</td><td>ID of the account where this cluster was created.</td></tr><tr><td>workspace_id</td><td>string</td><td>ID of the workspace where this cluster was created.</td></tr><tr><td>cluster_id</td><td>string</td><td>ID of the cluster for which this record is associated.</td></tr><tr><td>cluster_name</td><td>string</td><td>User defined name for the cluster.</td></tr><tr><td>owned_by</td><td>string</td><td>Username of the cluster owner. Defaults to the cluster creator, but can be changed through the [Clusters API](https://docs.databricks.com/api/workspace/clusters/changeowner).</td></tr><tr><td>create_time</td><td>timestamp</td><td>Timestamp of the change to this compute definition.</td></tr><tr><td>delete_time</td><td>timestamp</td><td>Timestamp of when the cluster wa
# ...

# %%
display(spark.sql("""SELECT change_time, cluster_id, event_type, details
FROM system.compute.clusters      
WHERE change_time > now() - INTERVAL '1 DAY'
ORDER BY change_time DESC;
"""))
# Out:
# [UNRESOLVED_COLUMN.WITH_SUGGESTION] A column, variable, or function parameter with name `timestamp` cannot be resolved. Did you mean one of the following? [`tags`, `owned_by`, `change_time`, `cluster_id`, `cluster_name`]. SQLSTATE: 42703
# Error: ---------------------------------------------------------------------------
#
# AnalysisException                         Traceback (most recent call last)
#
# File ~/.ipykernel/6309/command--1-3127643069:1
#
# ----> 1 display(spark.sql("""SELECT timestamp, cluster_id, event_type, details
#
#       2 FROM system.compute.clusters
#
#       3 WHERE timestamp > now() - INTERVAL '1 DAY'
#
#       4 ORDER BY timestamp DESC;
#
#       5 """))
#
#
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:47, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#
#      45 start = time.perf_counter()
#
#      46 try:
#
# ---> 47     res = func(*args, **kwargs)
#
#      48     logger.log_success(
#
# ...
