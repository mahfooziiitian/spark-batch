# %%
# %sql
show tables in mgmt_stg.metadata
# Out:
# <div style="height:300px;overflow:auto;resize:both;"><table style="width:100%" class="searchable sortable"><thead><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>metadata</td><td>workspace_id_crosswalk_active_view</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_base</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_base_20241022</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_base_20241101</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_base_20241211</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_base_20241213</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_tenant_env_view</td><td>false</td></tr><tr><td>metadata</td><td>workspace_id_crosswalk_view</td><td>false</td></tr></tbody></table></div>
