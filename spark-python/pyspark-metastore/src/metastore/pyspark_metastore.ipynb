# %%
from pyspark.sql import SparkSession

# %%
import os
from pathlib import PurePath

hive_metastore_uri = PurePath(os.environ["DERBY_HOME"]).as_posix()
datawarehouse = os.environ["SPARK_WAREHOUSE"]
os.environ["JAVA_HOME"] = PurePath(os.environ["JAVA_HOME_11"]).as_posix()

# %%
spark = (
    SparkSession.builder.appName("metastore")
    .config("spark.sql.warehouse.dir", datawarehouse)
    .master("local[*]")
    .getOrCreate()
)
# Out:
# 25/09/30 01:15:55 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
print(spark.conf.get("spark.sql.catalogImplementation"))
# Out:
# in-memory
