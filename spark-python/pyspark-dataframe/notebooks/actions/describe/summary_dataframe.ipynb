# %%
from pyspark.sql import SparkSession

# %%
import os
from pathlib import PurePath
HiveMetastoreUri = PurePath(os.environ["derby.system.home"]).as_posix()
Datawarehouse = os.environ["SPARK_WAREHOUSE"]
print(f"Hive metastore uri : {HiveMetastoreUri}")
print(Datawarehouse)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 from pathlib import PurePath
# ----> 3 HiveMetastoreUri = PurePath(os.environ["derby.system.home"]).as_posix()
#       4 Datawarehouse = os.environ["SPARK_WAREHOUSE"]
#       5 print(f"Hive metastore uri : {HiveMetastoreUri}")
#
# File <frozen os>:717, in __getitem__(self, key)
#
# KeyError: 'derby.system.home'

# %%
spark = SparkSession.builder.appName("metastore").master("local[*]")\
    .config("spark.sql.warehouse.dir", Datawarehouse) \
    .config("spark.driver.extraJavaOptions", f'-Dderby.system.home={HiveMetastoreUri}')\
    .enableHiveSupport().getOrCreate()

# %%
from datetime import datetime,date
rdd = spark.sparkContext.parallelize([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
])
df = spark.createDataFrame(rdd, schema=['a', 'b', 'c', 'd', 'e'])

# %%
df.select("a", "b", "c").describe().show()
# Out:
# +-------+---+---+-------+
# |summary|  a|  b|      c|
# +-------+---+---+-------+
# |  count|  3|  3|      3|
# |   mean|2.0|3.0|   null|
# | stddev|1.0|1.0|   null|
# |    min|  1|2.0|string1|
# |    max|  3|4.0|string3|
# +-------+---+---+-------+
